# %%
# !pip install -r ./drive/MyDrive/DeepSAD/requirements.txt

# %%
# !python ./drive/MyDrive/DeepSAD/src/main.py fmnist fmnist_LeNet ./drive/MyDrive/DeepSAD/log/fmnist_param1_0/ ./drive/MyDrive/DeepSAD/data/ --ratio_known_outlier 0 --ratio_pollution 0 --lr 0.001 --n_epochs 150 --lr_milestone 50 --batch_size 128 --weight_decay 0.5e-6 --pretrain True --ae_lr 0.0001 --ae_n_epochs 150 --ae_batch_size 128 --ae_weight_decay 0.5e-3 --normal_class 2 --known_outlier_class 1 --n_known_outlier_classes 1 --seed 8
# Out:
# 流式输出内容被截断，只能显示最后 5000 行内容。
# INFO:root:| Epoch: 138/150 | Train Time: 0.576s | Train Loss: 0.002772 |
# INFO:root:| Epoch: 139/150 | Train Time: 0.574s | Train Loss: 0.002134 |
# INFO:root:| Epoch: 140/150 | Train Time: 0.580s | Train Loss: 0.002281 |
# INFO:root:| Epoch: 141/150 | Train Time: 0.585s | Train Loss: 0.001920 |
# INFO:root:| Epoch: 142/150 | Train Time: 0.590s | Train Loss: 0.001854 |
# INFO:root:| Epoch: 143/150 | Train Time: 0.573s | Train Loss: 0.001970 |
# INFO:root:| Epoch: 144/150 | Train Time: 0.591s | Train Loss: 0.002121 |
# INFO:root:| Epoch: 145/150 | Train Time: 0.568s | Train Loss: 0.002476 |
# INFO:root:| Epoch: 146/150 | Train Time: 0.581s | Train Loss: 0.001589 |
# INFO:root:| Epoch: 147/150 | Train Time: 0.601s | Train Loss: 0.002065 |
# INFO:root:| Epoch: 148/150 | Train Time: 0.582s | Train Loss: 0.001615 |
# INFO:root:| Epoch: 149/150 | Train Time: 0.577s | Train Loss: 0.002372 |
# ...

# %%
# !python ./drive/MyDrive/DeepSAD/src/main.py fmnist fmnist_LeNet ./drive/MyDrive/DeepSAD/log/fmnist_param2_0/ ./drive/MyDrive/DeepSAD/data/ --ratio_known_outlier 0.05 --ratio_pollution 0 --lr 0.001 --n_epochs 150 --lr_milestone 50 --batch_size 128 --weight_decay 0.5e-6 --pretrain True --ae_lr 0.0001 --ae_n_epochs 150 --ae_batch_size 128 --ae_weight_decay 0.5e-3 --normal_class 2 --known_outlier_class 1 --n_known_outlier_classes 1 --seed 8
# Out:
# 流式输出内容被截断，只能显示最后 5000 行内容。
# INFO:root:| Epoch: 138/150 | Train Time: 0.649s | Train Loss: 0.009974 |
# INFO:root:| Epoch: 139/150 | Train Time: 0.616s | Train Loss: 0.010380 |
# INFO:root:| Epoch: 140/150 | Train Time: 0.629s | Train Loss: 0.011077 |
# INFO:root:| Epoch: 141/150 | Train Time: 0.612s | Train Loss: 0.010512 |
# INFO:root:| Epoch: 142/150 | Train Time: 0.631s | Train Loss: 0.011070 |
# INFO:root:| Epoch: 143/150 | Train Time: 0.620s | Train Loss: 0.011565 |
# INFO:root:| Epoch: 144/150 | Train Time: 0.627s | Train Loss: 0.009994 |
# INFO:root:| Epoch: 145/150 | Train Time: 0.655s | Train Loss: 0.008943 |
# INFO:root:| Epoch: 146/150 | Train Time: 0.634s | Train Loss: 0.009853 |
# INFO:root:| Epoch: 147/150 | Train Time: 0.614s | Train Loss: 0.010872 |
# INFO:root:| Epoch: 148/150 | Train Time: 0.623s | Train Loss: 0.010785 |
# INFO:root:| Epoch: 149/150 | Train Time: 0.624s | Train Loss: 0.009725 |
# ...

# %%
# !python ./drive/MyDrive/DeepSAD/src/main.py fmnist fmnist_LeNet ./drive/MyDrive/DeepSAD/log/fmnist_param3_0/ ./drive/MyDrive/DeepSAD/data/ --ratio_known_outlier 0.05 --ratio_pollution 0.1 --lr 0.001 --n_epochs 150 --lr_milestone 50 --batch_size 128 --weight_decay 0.5e-6 --pretrain True --ae_lr 0.0001 --ae_n_epochs 150 --ae_batch_size 128 --ae_weight_decay 0.5e-3 --normal_class 2 --known_outlier_class 1 --n_known_outlier_classes 0 --seed 8
# Out:
# INFO:root:Log file is ./drive/MyDrive/DeepSAD/log/fmnist_param3_0//log.txt
# INFO:root:Data path is ./drive/MyDrive/DeepSAD/data/
# INFO:root:Export path is ./drive/MyDrive/DeepSAD/log/fmnist_param3_0/
# INFO:root:Dataset: fmnist
# INFO:root:Normal class: 2
# INFO:root:Ratio of labeled normal train samples: 0.00
# INFO:root:Ratio of labeled anomalous samples: 0.05
# INFO:root:Pollution ratio of unlabeled train data: 0.10
# INFO:root:Number of known anomaly classes: 0
# INFO:root:Network: fmnist_LeNet
# INFO:root:Eta-parameter: 1.00
# INFO:root:Set seed to 8.
# INFO:root:Computation device: cuda
# INFO:root:Number of threads: 0
# INFO:root:Number of dataloader workers: 0
# Traceback (most recent call last):
#   File "./drive/MyDrive/DeepSAD/src/main.py", line 241, in <module>
#     main()
#   File "/usr/local/lib/python3.7/dist-packages/click/core.py", line 764, in __call__
#     return self.main(*args, **kwargs)
# ...

# %%
# !python ./drive/MyDrive/DeepSAD/src/main.py fmnist fmnist_LeNet ./drive/MyDrive/DeepSAD/log/fmnist_param1_3/ ./drive/MyDrive/DeepSAD/data/ --ratio_known_outlier 0.1 --ratio_pollution 0 --lr 0.001 --n_epochs 150 --lr_milestone 50 --batch_size 128 --weight_decay 0.5e-6 --pretrain True --ae_lr 0.0001 --ae_n_epochs 150 --ae_batch_size 128 --ae_weight_decay 0.5e-3 --normal_class 2 --known_outlier_class 1 --n_known_outlier_classes 1 --seed 8
# Out:
# 流式输出内容被截断，只能显示最后 5000 行内容。
# INFO:root:| Epoch: 138/150 | Train Time: 0.645s | Train Loss: 0.003042 |
# INFO:root:| Epoch: 139/150 | Train Time: 0.673s | Train Loss: 0.002293 |
# INFO:root:| Epoch: 140/150 | Train Time: 0.656s | Train Loss: 0.002087 |
# INFO:root:| Epoch: 141/150 | Train Time: 0.645s | Train Loss: 0.002283 |
# INFO:root:| Epoch: 142/150 | Train Time: 0.657s | Train Loss: 0.002324 |
# INFO:root:| Epoch: 143/150 | Train Time: 0.667s | Train Loss: 0.002306 |
# INFO:root:| Epoch: 144/150 | Train Time: 0.662s | Train Loss: 0.002427 |
# INFO:root:| Epoch: 145/150 | Train Time: 0.654s | Train Loss: 0.002692 |
# INFO:root:| Epoch: 146/150 | Train Time: 0.646s | Train Loss: 0.002008 |
# INFO:root:| Epoch: 147/150 | Train Time: 0.677s | Train Loss: 0.002631 |
# INFO:root:| Epoch: 148/150 | Train Time: 0.686s | Train Loss: 0.002522 |
# INFO:root:| Epoch: 149/150 | Train Time: 0.645s | Train Loss: 0.002568 |
# ...

# %%
# !python ./drive/MyDrive/DeepSAD/src/main.py fmnist fmnist_LeNet ./drive/MyDrive/DeepSAD/log/fmnist_param1_4/ ./drive/MyDrive/DeepSAD/data/ --ratio_known_outlier 0.2 --ratio_pollution 0 --lr 0.001 --n_epochs 150 --lr_milestone 50 --batch_size 128 --weight_decay 0.5e-6 --pretrain True --ae_lr 0.0001 --ae_n_epochs 150 --ae_batch_size 128 --ae_weight_decay 0.5e-3 --normal_class 2 --known_outlier_class 1 --n_known_outlier_classes 1 --seed 8
# Out:
# 流式输出内容被截断，只能显示最后 5000 行内容。
# INFO:root:| Epoch: 138/150 | Train Time: 0.724s | Train Loss: 0.002131 |
# INFO:root:| Epoch: 139/150 | Train Time: 0.728s | Train Loss: 0.001697 |
# INFO:root:| Epoch: 140/150 | Train Time: 0.735s | Train Loss: 0.002001 |
# INFO:root:| Epoch: 141/150 | Train Time: 0.715s | Train Loss: 0.001933 |
# INFO:root:| Epoch: 142/150 | Train Time: 0.730s | Train Loss: 0.001807 |
# INFO:root:| Epoch: 143/150 | Train Time: 0.731s | Train Loss: 0.001941 |
# INFO:root:| Epoch: 144/150 | Train Time: 0.730s | Train Loss: 0.002523 |
# INFO:root:| Epoch: 145/150 | Train Time: 0.733s | Train Loss: 0.002454 |
# INFO:root:| Epoch: 146/150 | Train Time: 0.721s | Train Loss: 0.002146 |
# INFO:root:| Epoch: 147/150 | Train Time: 0.719s | Train Loss: 0.002287 |
# INFO:root:| Epoch: 148/150 | Train Time: 0.715s | Train Loss: 0.001643 |
# INFO:root:| Epoch: 149/150 | Train Time: 0.759s | Train Loss: 0.001476 |
# ...
