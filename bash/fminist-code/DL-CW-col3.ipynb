# %%
# !pip install -r ./drive/MyDrive/DeepSAD/requirements.txt

# %%
# !python ./drive/MyDrive/DeepSAD/src/main.py fmnist fmnist_LeNet ./drive/MyDrive/DeepSAD/log/fmnist_param1_2/ ./drive/MyDrive/DeepSAD/data/ --ratio_known_outlier 0.05 --ratio_pollution 0 --lr 0.001 --n_epochs 150 --lr_milestone 50 --batch_size 128 --weight_decay 0.5e-6 --pretrain True --ae_lr 0.0001 --ae_n_epochs 150 --ae_batch_size 128 --ae_weight_decay 0.5e-3 --normal_class 2 --known_outlier_class 1 --n_known_outlier_classes 1 --seed 8
# Out:
# 流式输出内容被截断，只能显示最后 5000 行内容。
# INFO:root:| Epoch: 138/150 | Train Time: 0.604s | Train Loss: 0.009974 |
# INFO:root:| Epoch: 139/150 | Train Time: 0.610s | Train Loss: 0.010380 |
# INFO:root:| Epoch: 140/150 | Train Time: 0.615s | Train Loss: 0.011077 |
# INFO:root:| Epoch: 141/150 | Train Time: 0.605s | Train Loss: 0.010512 |
# INFO:root:| Epoch: 142/150 | Train Time: 0.635s | Train Loss: 0.011070 |
# INFO:root:| Epoch: 143/150 | Train Time: 0.617s | Train Loss: 0.011565 |
# INFO:root:| Epoch: 144/150 | Train Time: 0.612s | Train Loss: 0.009994 |
# INFO:root:| Epoch: 145/150 | Train Time: 0.625s | Train Loss: 0.008943 |
# INFO:root:| Epoch: 146/150 | Train Time: 0.613s | Train Loss: 0.009853 |
# INFO:root:| Epoch: 147/150 | Train Time: 0.606s | Train Loss: 0.010872 |
# INFO:root:| Epoch: 148/150 | Train Time: 0.605s | Train Loss: 0.010785 |
# INFO:root:| Epoch: 149/150 | Train Time: 0.623s | Train Loss: 0.009725 |
# ...

# %%
# !python ./drive/MyDrive/DeepSAD/src/main.py fmnist fmnist_LeNet ./drive/MyDrive/DeepSAD/log/fmnist_param2_2/ ./drive/MyDrive/DeepSAD/data/ --ratio_known_outlier 0.05 --ratio_pollution 0.05 --lr 0.001 --n_epochs 150 --lr_milestone 50 --batch_size 128 --weight_decay 0.5e-6 --pretrain True --ae_lr 0.0001 --ae_n_epochs 150 --ae_batch_size 128 --ae_weight_decay 0.5e-3 --normal_class 2 --known_outlier_class 1 --n_known_outlier_classes 1 --seed 8
# Out:
# 流式输出内容被截断，只能显示最后 5000 行内容。
# INFO:root:| Epoch: 138/150 | Train Time: 0.640s | Train Loss: 0.015469 |
# INFO:root:| Epoch: 139/150 | Train Time: 0.645s | Train Loss: 0.016122 |
# INFO:root:| Epoch: 140/150 | Train Time: 0.639s | Train Loss: 0.014276 |
# INFO:root:| Epoch: 141/150 | Train Time: 0.652s | Train Loss: 0.014170 |
# INFO:root:| Epoch: 142/150 | Train Time: 0.662s | Train Loss: 0.014065 |
# INFO:root:| Epoch: 143/150 | Train Time: 0.636s | Train Loss: 0.014842 |
# INFO:root:| Epoch: 144/150 | Train Time: 0.651s | Train Loss: 0.014124 |
# INFO:root:| Epoch: 145/150 | Train Time: 0.636s | Train Loss: 0.013637 |
# INFO:root:| Epoch: 146/150 | Train Time: 0.640s | Train Loss: 0.013115 |
# INFO:root:| Epoch: 147/150 | Train Time: 0.671s | Train Loss: 0.014388 |
# INFO:root:| Epoch: 148/150 | Train Time: 0.632s | Train Loss: 0.015264 |
# INFO:root:| Epoch: 149/150 | Train Time: 0.647s | Train Loss: 0.013776 |
# ...

# %%
# !python ./drive/MyDrive/DeepSAD/src/main.py fmnist fmnist_LeNet ./drive/MyDrive/DeepSAD/log/fmnist_param3_2/ ./drive/MyDrive/DeepSAD/data/ --ratio_known_outlier 0.05 --ratio_pollution 0.1 --lr 0.001 --n_epochs 150 --lr_milestone 50 --batch_size 128 --weight_decay 0.5e-6 --pretrain True --ae_lr 0.0001 --ae_n_epochs 150 --ae_batch_size 128 --ae_weight_decay 0.5e-3 --normal_class 2 --known_outlier_class 1 --n_known_outlier_classes 2 --seed 8
# Out:
# 流式输出内容被截断，只能显示最后 5000 行内容。
# INFO:root:| Epoch: 138/150 | Train Time: 0.690s | Train Loss: 0.015665 |
# INFO:root:| Epoch: 139/150 | Train Time: 0.676s | Train Loss: 0.016083 |
# INFO:root:| Epoch: 140/150 | Train Time: 0.678s | Train Loss: 0.017522 |
# INFO:root:| Epoch: 141/150 | Train Time: 0.718s | Train Loss: 0.017371 |
# INFO:root:| Epoch: 142/150 | Train Time: 0.674s | Train Loss: 0.016087 |
# INFO:root:| Epoch: 143/150 | Train Time: 0.686s | Train Loss: 0.017533 |
# INFO:root:| Epoch: 144/150 | Train Time: 0.698s | Train Loss: 0.016220 |
# INFO:root:| Epoch: 145/150 | Train Time: 0.703s | Train Loss: 0.014156 |
# INFO:root:| Epoch: 146/150 | Train Time: 0.696s | Train Loss: 0.015984 |
# INFO:root:| Epoch: 147/150 | Train Time: 0.732s | Train Loss: 0.018710 |
# INFO:root:| Epoch: 148/150 | Train Time: 0.666s | Train Loss: 0.017048 |
# INFO:root:| Epoch: 149/150 | Train Time: 0.687s | Train Loss: 0.015711 |
# ...

# %%
# !python ./drive/MyDrive/DeepSAD/src/main.py fmnist fmnist_LeNet ./drive/MyDrive/DeepSAD/log/fmnist_param3_3/ ./drive/MyDrive/DeepSAD/data/ --ratio_known_outlier 0.05 --ratio_pollution 0.1 --lr 0.001 --n_epochs 150 --lr_milestone 50 --batch_size 128 --weight_decay 0.5e-6 --pretrain True --ae_lr 0.0001 --ae_n_epochs 150 --ae_batch_size 128 --ae_weight_decay 0.5e-3 --normal_class 2 --known_outlier_class 1 --n_known_outlier_classes 3 --seed 8
# Out:
# 流式输出内容被截断，只能显示最后 5000 行内容。
# INFO:root:| Epoch: 138/150 | Train Time: 0.684s | Train Loss: 0.013250 |
# INFO:root:| Epoch: 139/150 | Train Time: 0.698s | Train Loss: 0.013445 |
# INFO:root:| Epoch: 140/150 | Train Time: 0.718s | Train Loss: 0.015209 |
# INFO:root:| Epoch: 141/150 | Train Time: 0.684s | Train Loss: 0.015005 |
# INFO:root:| Epoch: 142/150 | Train Time: 0.681s | Train Loss: 0.014534 |
# INFO:root:| Epoch: 143/150 | Train Time: 0.688s | Train Loss: 0.014886 |
# INFO:root:| Epoch: 144/150 | Train Time: 0.698s | Train Loss: 0.013918 |
# INFO:root:| Epoch: 145/150 | Train Time: 0.696s | Train Loss: 0.012825 |
# INFO:root:| Epoch: 146/150 | Train Time: 0.687s | Train Loss: 0.016529 |
# INFO:root:| Epoch: 147/150 | Train Time: 0.703s | Train Loss: 0.018797 |
# INFO:root:| Epoch: 148/150 | Train Time: 0.692s | Train Loss: 0.014810 |
# INFO:root:| Epoch: 149/150 | Train Time: 0.691s | Train Loss: 0.013760 |
# ...

# %%
# !python ./drive/MyDrive/DeepSAD/src/main.py fmnist fmnist_LeNet ./drive/MyDrive/DeepSAD/log/fmnist_param3_4/ ./drive/MyDrive/DeepSAD/data/ --ratio_known_outlier 0.05 --ratio_pollution 0.1 --lr 0.001 --n_epochs 150 --lr_milestone 50 --batch_size 128 --weight_decay 0.5e-6 --pretrain True --ae_lr 0.0001 --ae_n_epochs 150 --ae_batch_size 128 --ae_weight_decay 0.5e-3 --normal_class 2 --known_outlier_class 1 --n_known_outlier_classes 5 --seed 8
# Out:
# 流式输出内容被截断，只能显示最后 5000 行内容。
# INFO:root:| Epoch: 138/150 | Train Time: 0.678s | Train Loss: 0.014597 |
# INFO:root:| Epoch: 139/150 | Train Time: 0.685s | Train Loss: 0.015585 |
# INFO:root:| Epoch: 140/150 | Train Time: 0.690s | Train Loss: 0.017299 |
# INFO:root:| Epoch: 141/150 | Train Time: 0.677s | Train Loss: 0.018343 |
# INFO:root:| Epoch: 142/150 | Train Time: 0.689s | Train Loss: 0.016502 |
# INFO:root:| Epoch: 143/150 | Train Time: 0.676s | Train Loss: 0.017079 |
# INFO:root:| Epoch: 144/150 | Train Time: 0.678s | Train Loss: 0.016151 |
# INFO:root:| Epoch: 145/150 | Train Time: 0.682s | Train Loss: 0.014192 |
# INFO:root:| Epoch: 146/150 | Train Time: 0.689s | Train Loss: 0.016441 |
# INFO:root:| Epoch: 147/150 | Train Time: 0.702s | Train Loss: 0.019096 |
# INFO:root:| Epoch: 148/150 | Train Time: 0.690s | Train Loss: 0.016416 |
# INFO:root:| Epoch: 149/150 | Train Time: 0.686s | Train Loss: 0.015901 |
# ...
