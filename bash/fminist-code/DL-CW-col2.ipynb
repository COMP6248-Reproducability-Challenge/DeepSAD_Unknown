# %%
# !pip install -r ./drive/MyDrive/DeepSAD/requirements.txt

# %%
# !python ./drive/MyDrive/DeepSAD/src/main.py fmnist fmnist_LeNet ./drive/MyDrive/DeepSAD/log/fmnist_param1_1/ ./drive/MyDrive/DeepSAD/data/ --ratio_known_outlier 0.01 --ratio_pollution 0 --lr 0.001 --n_epochs 150 --lr_milestone 50 --batch_size 128 --weight_decay 0.5e-6 --pretrain True --ae_lr 0.0001 --ae_n_epochs 150 --ae_batch_size 128 --ae_weight_decay 0.5e-3 --normal_class 2 --known_outlier_class 1 --n_known_outlier_classes 1 --seed 8
# Out:
# 流式输出内容被截断，只能显示最后 5000 行内容。
# INFO:root:| Epoch: 138/150 | Train Time: 0.606s | Train Loss: 0.004948 |
# INFO:root:| Epoch: 139/150 | Train Time: 0.621s | Train Loss: 0.005414 |
# INFO:root:| Epoch: 140/150 | Train Time: 0.608s | Train Loss: 0.004653 |
# INFO:root:| Epoch: 141/150 | Train Time: 0.605s | Train Loss: 0.004773 |
# INFO:root:| Epoch: 142/150 | Train Time: 0.602s | Train Loss: 0.004846 |
# INFO:root:| Epoch: 143/150 | Train Time: 0.609s | Train Loss: 0.004834 |
# INFO:root:| Epoch: 144/150 | Train Time: 0.637s | Train Loss: 0.004128 |
# INFO:root:| Epoch: 145/150 | Train Time: 0.611s | Train Loss: 0.004552 |
# INFO:root:| Epoch: 146/150 | Train Time: 0.602s | Train Loss: 0.005126 |
# INFO:root:| Epoch: 147/150 | Train Time: 0.604s | Train Loss: 0.004528 |
# INFO:root:| Epoch: 148/150 | Train Time: 0.593s | Train Loss: 0.005059 |
# INFO:root:| Epoch: 149/150 | Train Time: 0.599s | Train Loss: 0.004886 |
# ...

# %%
# !python ./drive/MyDrive/DeepSAD/src/main.py fmnist fmnist_LeNet ./drive/MyDrive/DeepSAD/log/fmnist_param2_1/ ./drive/MyDrive/DeepSAD/data/ --ratio_known_outlier 0.05 --ratio_pollution 0.01 --lr 0.001 --n_epochs 150 --lr_milestone 50 --batch_size 128 --weight_decay 0.5e-6 --pretrain True --ae_lr 0.0001 --ae_n_epochs 150 --ae_batch_size 128 --ae_weight_decay 0.5e-3 --normal_class 2 --known_outlier_class 1 --n_known_outlier_classes 1 --seed 8
# Out:
# 流式输出内容被截断，只能显示最后 5000 行内容。
# INFO:root:| Epoch: 138/150 | Train Time: 0.620s | Train Loss: 0.010352 |
# INFO:root:| Epoch: 139/150 | Train Time: 0.623s | Train Loss: 0.009826 |
# INFO:root:| Epoch: 140/150 | Train Time: 0.616s | Train Loss: 0.011139 |
# INFO:root:| Epoch: 141/150 | Train Time: 0.614s | Train Loss: 0.013390 |
# INFO:root:| Epoch: 142/150 | Train Time: 0.614s | Train Loss: 0.009929 |
# INFO:root:| Epoch: 143/150 | Train Time: 0.621s | Train Loss: 0.011650 |
# INFO:root:| Epoch: 144/150 | Train Time: 0.615s | Train Loss: 0.010730 |
# INFO:root:| Epoch: 145/150 | Train Time: 0.615s | Train Loss: 0.010252 |
# INFO:root:| Epoch: 146/150 | Train Time: 0.612s | Train Loss: 0.010663 |
# INFO:root:| Epoch: 147/150 | Train Time: 0.638s | Train Loss: 0.010028 |
# INFO:root:| Epoch: 148/150 | Train Time: 0.700s | Train Loss: 0.010259 |
# INFO:root:| Epoch: 149/150 | Train Time: 0.628s | Train Loss: 0.008996 |
# ...

# %%
# !python ./drive/MyDrive/DeepSAD/src/main.py fmnist fmnist_LeNet ./drive/MyDrive/DeepSAD/log/fmnist_param3_1/ ./drive/MyDrive/DeepSAD/data/ --ratio_known_outlier 0.05 --ratio_pollution 0.1 --lr 0.001 --n_epochs 150 --lr_milestone 50 --batch_size 128 --weight_decay 0.5e-6 --pretrain True --ae_lr 0.0001 --ae_n_epochs 150 --ae_batch_size 128 --ae_weight_decay 0.5e-3 --normal_class 2 --known_outlier_class 1 --n_known_outlier_classes 1 --seed 8
# Out:
# 流式输出内容被截断，只能显示最后 5000 行内容。
# INFO:root:| Epoch: 138/150 | Train Time: 0.682s | Train Loss: 0.008932 |
# INFO:root:| Epoch: 139/150 | Train Time: 0.694s | Train Loss: 0.011006 |
# INFO:root:| Epoch: 140/150 | Train Time: 0.687s | Train Loss: 0.010830 |
# INFO:root:| Epoch: 141/150 | Train Time: 0.680s | Train Loss: 0.010480 |
# INFO:root:| Epoch: 142/150 | Train Time: 0.688s | Train Loss: 0.014873 |
# INFO:root:| Epoch: 143/150 | Train Time: 0.684s | Train Loss: 0.011159 |
# INFO:root:| Epoch: 144/150 | Train Time: 0.704s | Train Loss: 0.010757 |
# INFO:root:| Epoch: 145/150 | Train Time: 0.679s | Train Loss: 0.008611 |
# INFO:root:| Epoch: 146/150 | Train Time: 0.671s | Train Loss: 0.009668 |
# INFO:root:| Epoch: 147/150 | Train Time: 0.689s | Train Loss: 0.010498 |
# INFO:root:| Epoch: 148/150 | Train Time: 0.669s | Train Loss: 0.009844 |
# INFO:root:| Epoch: 149/150 | Train Time: 0.664s | Train Loss: 0.009527 |
# ...

# %%
# !python ./drive/MyDrive/DeepSAD/src/main.py fmnist fmnist_LeNet ./drive/MyDrive/DeepSAD/log/fmnist_param2_3/ ./drive/MyDrive/DeepSAD/data/ --ratio_known_outlier 0.05 --ratio_pollution 0.1 --lr 0.001 --n_epochs 150 --lr_milestone 50 --batch_size 128 --weight_decay 0.5e-6 --pretrain True --ae_lr 0.0001 --ae_n_epochs 150 --ae_batch_size 128 --ae_weight_decay 0.5e-3 --normal_class 2 --known_outlier_class 1 --n_known_outlier_classes 1 --seed 8
# Out:
# 流式输出内容被截断，只能显示最后 5000 行内容。
# INFO:root:| Epoch: 138/150 | Train Time: 0.673s | Train Loss: 0.008932 |
# INFO:root:| Epoch: 139/150 | Train Time: 0.676s | Train Loss: 0.011006 |
# INFO:root:| Epoch: 140/150 | Train Time: 0.683s | Train Loss: 0.010830 |
# INFO:root:| Epoch: 141/150 | Train Time: 0.668s | Train Loss: 0.010480 |
# INFO:root:| Epoch: 142/150 | Train Time: 0.695s | Train Loss: 0.014873 |
# INFO:root:| Epoch: 143/150 | Train Time: 0.692s | Train Loss: 0.011159 |
# INFO:root:| Epoch: 144/150 | Train Time: 0.670s | Train Loss: 0.010757 |
# INFO:root:| Epoch: 145/150 | Train Time: 0.679s | Train Loss: 0.008611 |
# INFO:root:| Epoch: 146/150 | Train Time: 0.678s | Train Loss: 0.009668 |
# INFO:root:| Epoch: 147/150 | Train Time: 0.694s | Train Loss: 0.010498 |
# INFO:root:| Epoch: 148/150 | Train Time: 0.676s | Train Loss: 0.009844 |
# INFO:root:| Epoch: 149/150 | Train Time: 0.683s | Train Loss: 0.009527 |
# ...

# %%
# !python ./drive/MyDrive/DeepSAD/src/main.py fmnist fmnist_LeNet ./drive/MyDrive/DeepSAD/log/fmnist_param2_4/ ./drive/MyDrive/DeepSAD/data/ --ratio_known_outlier 0.05 --ratio_pollution 0.2 --lr 0.001 --n_epochs 150 --lr_milestone 50 --batch_size 128 --weight_decay 0.5e-6 --pretrain True --ae_lr 0.0001 --ae_n_epochs 150 --ae_batch_size 128 --ae_weight_decay 0.5e-3 --normal_class 2 --known_outlier_class 1 --n_known_outlier_classes 1 --seed 8
# Out:
# 流式输出内容被截断，只能显示最后 5000 行内容。
# INFO:root:| Epoch: 138/150 | Train Time: 0.778s | Train Loss: 0.016153 |
# INFO:root:| Epoch: 139/150 | Train Time: 0.775s | Train Loss: 0.015805 |
# INFO:root:| Epoch: 140/150 | Train Time: 0.777s | Train Loss: 0.018300 |
# INFO:root:| Epoch: 141/150 | Train Time: 0.775s | Train Loss: 0.014065 |
# INFO:root:| Epoch: 142/150 | Train Time: 0.777s | Train Loss: 0.014072 |
# INFO:root:| Epoch: 143/150 | Train Time: 0.777s | Train Loss: 0.013011 |
# INFO:root:| Epoch: 144/150 | Train Time: 0.801s | Train Loss: 0.013749 |
# INFO:root:| Epoch: 145/150 | Train Time: 0.771s | Train Loss: 0.015762 |
# INFO:root:| Epoch: 146/150 | Train Time: 0.781s | Train Loss: 0.014424 |
# INFO:root:| Epoch: 147/150 | Train Time: 0.769s | Train Loss: 0.013998 |
# INFO:root:| Epoch: 148/150 | Train Time: 0.785s | Train Loss: 0.014086 |
# INFO:root:| Epoch: 149/150 | Train Time: 0.757s | Train Loss: 0.012675 |
# ...
